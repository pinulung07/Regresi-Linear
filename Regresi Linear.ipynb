# %%
print ("Muhamad Wino Jati Pinulung_202331205")

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
# Out:
# Muhamad Wino Jati Pinulung_202331205

# %%
df = pd.DataFrame([[151,63], [174,81], [138,56], [186,91], [128,47], [136,57], [179,76], [163,72], [152,62], [131,48]])
df.columns = ['tinggi', 'berat']
df
# Out:
#    tinggi  berat
# 0     151     63
# 1     174     81
# 2     138     56
# 3     186     91
# 4     128     47
# 5     136     57
# 6     179     76
# 7     163     72
# 8     152     62
# 9     131     48

# %%
df.columns = ['x', 'y']
print(df)
# Out:
#      x   y
# 0  151  63
# 1  174  81
# 2  138  56
# 3  186  91
# 4  128  47
# 5  136  57
# 6  179  76
# 7  163  72
# 8  152  62
# 9  131  48

# %%
df.corr()
# Out:
#          x        y
# x  1.00000  0.97713
# y  0.97713  1.00000

# %%
x_train = df['x'].values[:,np.newaxis]
y_train = df['y'].values

lm = LinearRegression()
lm.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_test = [[170], [171], [160], [180], [150]]
p = lm.predict(x_test)
print(p)
# Out:
# [76.22868928 76.90329973 69.48258478 82.97479377 62.73648029]

# %%
print('Coefficient : ' + str(lm.coef_))
print('Intercept : ' +str(lm.intercept_))
# Out:
# Coefficient : [0.67461045]
# Intercept : -38.45508707607701

# %%
pb = lm.predict(x_train)
dfc = pd.DataFrame({'x' : df['x'], 'y' :pb})
plt.scatter(df['x'], df['y'])
plt.plot(dfc['x'], dfc['y'], color = 'blue', linewidth = 1)
plt.xlabel('Tinggi dalam cm')
plt.ylabel(' Berat dalam kg')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
y_asli = [72, 62, 48]
y_hasil_prediksi = lm.predict ([[163], [152], [131]])
print(y_hasil_prediksi)
# Out:
# [71.50641613 64.08570119 49.91888176]

# %%
from sklearn.metrics import r2_score
akurasi = r2_score(y_asli, y_hasil_prediksi)
print(akurasi*100)
# Out:
# 97.1527929918931
